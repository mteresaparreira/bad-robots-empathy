# %%
import os
import glob
import subprocess

# %%
studyDataDirectory = '/Users/sukruthgl/Desktop/Spring/CS 5999 - MEng Project/StudyData/pilots'
studyUsers = os.listdir(studyDataDirectory)
studyUsers = [studyUser for studyUser in studyUsers if studyUser not in ('.DS_Store', 'participant_log.xlsx')]
print(studyUsers)
# Out:
# ['8006', '3260', '3518', '7444']

# %%
convertVideo(studyUsers)
# Out:
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.1.2_6 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [h264 @ 0x154604bd0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x154604bd0] decode_slice_header error
# [h264 @ 0x154604bd0] no frame!
# [matroska,webm @ 0x154704490] Could not find codec parameters for stream 0 (Video: h264, none, 1280x720): unspecified pixel format
# Consider increasing the value for the 'analyzeduration' (0) and 'probesize' (5000000) options
# Input #0, matroska,webm, from 'QID814_1682630752457.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, bitrate: N/A
#   Stream #0:0(eng): Video: h264, none, 1280x720, SAR 1:1 DAR 16:9, 1k tbr, 1k tbn (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# [h264 @ 0x15472b8e0] non-existing PPS 0 referenced
# [h264 @ 0x15472b8e0] decode_slice_header error
# [h264 @ 0x15472b8e0] no frame!
# [h264 @ 0x154734cf0] non-existing PPS 0 referenced
# [h264 @ 0x154734cf0] decode_slice_header error
# [h264 @ 0x154734cf0] no frame!
# [h264 @ 0x15473e100] non-existing PPS 0 referenced
# [h264 @ 0x15473e100] decode_slice_header error
# [h264 @ 0x15473e100] no frame!
# [h264 @ 0x154747510] non-existing PPS 0 referenced
# [h264 @ 0x154747510] decode_slice_header error
# [h264 @ 0x154747510] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154750920] non-existing PPS 0 referenced
# [h264 @ 0x154750920] decode_slice_header error
# [h264 @ 0x154750920] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15472b8e0] non-existing PPS 0 referenced
# [h264 @ 0x15472b8e0] decode_slice_header error
# [h264 @ 0x15472b8e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154734cf0] non-existing PPS 0 referenced
# [h264 @ 0x154734cf0] decode_slice_header error
# [h264 @ 0x154734cf0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15473e100] non-existing PPS 0 referenced
# [h264 @ 0x15473e100] decode_slice_header error
# [h264 @ 0x15473e100] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154747510] non-existing PPS 0 referenced
# [h264 @ 0x154747510] decode_slice_header error
# [h264 @ 0x154747510] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154750920] non-existing PPS 0 referenced
# [h264 @ 0x154750920] decode_slice_header error
# [h264 @ 0x154750920] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15472b8e0] non-existing PPS 0 referenced
# [h264 @ 0x15472b8e0] decode_slice_header error
# [h264 @ 0x15472b8e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154734cf0] non-existing PPS 0 referenced
# [h264 @ 0x154734cf0] decode_slice_header error
# [h264 @ 0x154734cf0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15473e100] non-existing PPS 0 referenced
# [h264 @ 0x15473e100] decode_slice_header error
# [h264 @ 0x15473e100] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154747510] non-existing PPS 0 referenced
# [h264 @ 0x154747510] decode_slice_header error
# [h264 @ 0x154747510] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154750920] non-existing PPS 0 referenced
# [h264 @ 0x154750920] decode_slice_header error
# [h264 @ 0x154750920] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15472b8e0] non-existing PPS 0 referenced
# [h264 @ 0x15472b8e0] decode_slice_header error
# [h264 @ 0x15472b8e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154734cf0] non-existing PPS 0 referenced
# [h264 @ 0x154734cf0] decode_slice_header error
# [h264 @ 0x154734cf0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15473e100] non-existing PPS 0 referenced
# [h264 @ 0x15473e100] decode_slice_header error
# [h264 @ 0x15473e100] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154747510] non-existing PPS 0 referenced
# [h264 @ 0x154747510] decode_slice_header error
# [h264 @ 0x154747510] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154750920] non-existing PPS 0 referenced
# [h264 @ 0x154750920] decode_slice_header error
# [h264 @ 0x154750920] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15472b8e0] non-existing PPS 0 referenced
# [h264 @ 0x15472b8e0] decode_slice_header error
# [h264 @ 0x15472b8e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154734cf0] non-existing PPS 0 referenced
# [h264 @ 0x154734cf0] decode_slice_header error
# [h264 @ 0x154734cf0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15473e100] non-existing PPS 0 referenced
# [h264 @ 0x15473e100] decode_slice_header error
# [h264 @ 0x15473e100] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154747510] non-existing PPS 0 referenced
# [h264 @ 0x154747510] decode_slice_header error
# [h264 @ 0x154747510] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154750920] non-existing PPS 0 referenced
# [h264 @ 0x154750920] decode_slice_header error
# [h264 @ 0x154750920] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15472b8e0] non-existing PPS 0 referenced
# [h264 @ 0x15472b8e0] decode_slice_header error
# [h264 @ 0x15472b8e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154734cf0] non-existing PPS 0 referenced
# [h264 @ 0x154734cf0] decode_slice_header error
# [h264 @ 0x154734cf0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15473e100] non-existing PPS 0 referenced
# [h264 @ 0x15473e100] decode_slice_header error
# [h264 @ 0x15473e100] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154747510] non-existing PPS 0 referenced
# [h264 @ 0x154747510] decode_slice_header error
# [h264 @ 0x154747510] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154750920] non-existing PPS 0 referenced
# [h264 @ 0x154750920] decode_slice_header error
# [h264 @ 0x154750920] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15472b8e0] non-existing PPS 0 referenced
# [h264 @ 0x15472b8e0] decode_slice_header error
# [h264 @ 0x15472b8e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154734cf0] non-existing PPS 0 referenced
# [h264 @ 0x154734cf0] decode_slice_header error
# [h264 @ 0x154734cf0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15473e100] non-existing PPS 0 referenced
# [h264 @ 0x15473e100] decode_slice_header error
# [h264 @ 0x15473e100] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154747510] non-existing PPS 0 referenced
# [h264 @ 0x154747510] decode_slice_header error
# [h264 @ 0x154747510] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x154750920] non-existing PPS 0 referenced
# [h264 @ 0x154750920] decode_slice_header error
# [h264 @ 0x154750920] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547068a0] non-existing PPS 0 referenced
# [h264 @ 0x1547068a0] decode_slice_header error
# [h264 @ 0x1547068a0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x15470fcb0] non-existing PPS 0 referenced
# [h264 @ 0x15470fcb0] decode_slice_header error
# [h264 @ 0x15470fcb0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547190c0] non-existing PPS 0 referenced
# [h264 @ 0x1547190c0] decode_slice_header error
# [h264 @ 0x1547190c0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x1547224d0] non-existing PPS 0 referenced
# [h264 @ 0x1547224d0] decode_slice_header error
# [h264 @ 0x1547224d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
#     Last message repeated 7 times
# Cannot determine format of input stream 0:0 after EOF
# Error marking filters as finished
# Conversion failed!
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.1.2_6 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [h264 @ 0x12c0043c0] non-existing PPS 0 referenced
#     Last message repeated 1 times
# [h264 @ 0x12c0043c0] decode_slice_header error
# [h264 @ 0x12c0043c0] no frame!
# [matroska,webm @ 0x12a704080] Could not find codec parameters for stream 0 (Video: h264, none, 1280x720): unspecified pixel format
# Consider increasing the value for the 'analyzeduration' (0) and 'probesize' (5000000) options
# Input #0, matroska,webm, from 'QID772_1682630436929.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, bitrate: N/A
#   Stream #0:0(eng): Video: h264, none, 1280x720, SAR 1:1 DAR 16:9, 1k tbr, 1k tbn (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [h264 @ 0x12c1060d0] non-existing PPS 0 referenced
# [h264 @ 0x12c1060d0] decode_slice_header error
# [h264 @ 0x12c1060d0] no frame!
# [h264 @ 0x12c10f4e0] non-existing PPS 0 referenced
# [h264 @ 0x12c10f4e0] decode_slice_header error
# [h264 @ 0x12c10f4e0] no frame!
# [h264 @ 0x12c1188f0] non-existing PPS 0 referenced
# [h264 @ 0x12c1188f0] decode_slice_header error
# [h264 @ 0x12c1188f0] no frame!
# [h264 @ 0x12c121d00] non-existing PPS 0 referenced
# [h264 @ 0x12c121d00] decode_slice_header error
# [h264 @ 0x12c121d00] no frame!
# [h264 @ 0x12c12b110] non-existing PPS 0 referenced
# [h264 @ 0x12c12b110] decode_slice_header error
# [h264 @ 0x12c12b110] no frame!
# [h264 @ 0x12c134520] non-existing PPS 0 referenced
# [h264 @ 0x12c134520] decode_slice_header error
# [h264 @ 0x12c134520] no frame!
# [h264 @ 0x12c13d930] non-existing PPS 0 referenced
# [h264 @ 0x12c13d930] decode_slice_header error
# [h264 @ 0x12c13d930] no frame!
# [h264 @ 0x12c146d40] non-existing PPS 0 referenced
# [h264 @ 0x12c146d40] decode_slice_header error
# [h264 @ 0x12c146d40] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c150150] non-existing PPS 0 referenced
# [h264 @ 0x12c150150] decode_slice_header error
# [h264 @ 0x12c150150] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c1060d0] non-existing PPS 0 referenced
# [h264 @ 0x12c1060d0] decode_slice_header error
# [h264 @ 0x12c1060d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c10f4e0] non-existing PPS 0 referenced
# [h264 @ 0x12c10f4e0] decode_slice_header error
# [h264 @ 0x12c10f4e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c1188f0] non-existing PPS 0 referenced
# [h264 @ 0x12c1188f0] decode_slice_header error
# [h264 @ 0x12c1188f0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c121d00] non-existing PPS 0 referenced
# [h264 @ 0x12c121d00] decode_slice_header error
# [h264 @ 0x12c121d00] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c12b110] non-existing PPS 0 referenced
# [h264 @ 0x12c12b110] decode_slice_header error
# [h264 @ 0x12c12b110] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c134520] non-existing PPS 0 referenced
# [h264 @ 0x12c134520] decode_slice_header error
# [h264 @ 0x12c134520] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c13d930] non-existing PPS 0 referenced
# [h264 @ 0x12c13d930] decode_slice_header error
# [h264 @ 0x12c13d930] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c146d40] non-existing PPS 0 referenced
# [h264 @ 0x12c146d40] decode_slice_header error
# [h264 @ 0x12c146d40] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c150150] non-existing PPS 0 referenced
# [h264 @ 0x12c150150] decode_slice_header error
# [h264 @ 0x12c150150] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c1060d0] non-existing PPS 0 referenced
# [h264 @ 0x12c1060d0] decode_slice_header error
# [h264 @ 0x12c1060d0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c10f4e0] non-existing PPS 0 referenced
# [h264 @ 0x12c10f4e0] decode_slice_header error
# [h264 @ 0x12c10f4e0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# [h264 @ 0x12c1188f0] non-existing PPS 0 referenced
# [h264 @ 0x12c1188f0] decode_slice_header error
# [h264 @ 0x12c1188f0] no frame!
# Error while decoding stream #0:0: Invalid data found when processing input
# ...
# [libx264 @ 0x1550072c0] frame P:44    Avg QP:22.18  size:  3096
# [libx264 @ 0x1550072c0] frame B:110   Avg QP:24.39  size:   541
# [libx264 @ 0x1550072c0] consecutive B-frames:  4.5%  1.3%  3.9% 90.3%
# [libx264 @ 0x1550072c0] mb I  I16..4: 17.2% 61.2% 21.6%
# [libx264 @ 0x1550072c0] mb P  I16..4:  2.7%  5.0%  0.2%  P16..4: 32.5%  8.7%  4.1%  0.0%  0.0%    skip:46.7%
# [libx264 @ 0x1550072c0] mb B  I16..4:  0.3%  0.4%  0.0%  B16..8: 26.0%  0.9%  0.1%  direct: 0.6%  skip:71.8%  L0:45.2% L1:52.0% BI: 2.8%
# [libx264 @ 0x1550072c0] 8x8 transform intra:61.7% inter:71.6%
# [libx264 @ 0x1550072c0] coded y,uvDC,uvAC intra: 25.8% 35.0% 2.3% inter: 5.2% 4.2% 0.0%
# [libx264 @ 0x1550072c0] i16 v,h,dc,p: 36% 24% 19% 20%
# [libx264 @ 0x1550072c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 14% 35%  2%  2%  3%  2%  3%  2%
# [libx264 @ 0x1550072c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 48% 15% 14%  4%  5%  5%  3%  4%  3%
# [libx264 @ 0x1550072c0] i8c dc,h,v,p: 61% 17% 18%  4%
# [libx264 @ 0x1550072c0] Weighted P-Frames: Y:9.1% UV:4.5%
# [libx264 @ 0x1550072c0] ref P L0: 64.9% 15.6% 16.4%  3.0%  0.1%
# [libx264 @ 0x1550072c0] ref B L0: 92.1%  7.0%  0.9%
# [libx264 @ 0x1550072c0] ref B L1: 96.8%  3.2%
# [libx264 @ 0x1550072c0] kb/s:316.76
# [aac @ 0x155008390] Qavg: 118.274
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.1.2_6 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, matroska,webm, from 'QID877_1682631150379.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Video: h264 (Baseline), yuv420p(tv, bt709/bt709/iec61966-2-1, progressive), 640x480, SAR 1:1 DAR 4:3, 30 fps, 30 tbr, 1k tbn (default)
#   Stream #0:1(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (opus (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x13af074a0] using SAR=1/1
# [libx264 @ 0x13af074a0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x13af074a0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x13af074a0] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/Users/sukruthgl/Desktop/Spring/CS 5999 - MEng Project/StudyData/pilots/7444/mp4StudyVideo/QID877_1682631150379.mp4':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709/bt709/iec61966-2-1, progressive), 640x480 [SAR 1:1 DAR 4:3], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       encoder         : Lavc59.37.100 aac
# frame=  363 fps=0.0 q=-1.0 Lsize=     409kB time=00:00:12.07 bitrate= 277.4kbits/s dup=2 drop=0 speed=25.9x
# video:293kB audio:102kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.438562%
# [libx264 @ 0x13af074a0] frame I:2     Avg QP:16.66  size: 11916
# [libx264 @ 0x13af074a0] frame P:185   Avg QP:20.08  size:  1291
# [libx264 @ 0x13af074a0] frame B:176   Avg QP:19.19  size:   208
# [libx264 @ 0x13af074a0] consecutive B-frames: 34.2%  2.2%  4.1% 59.5%
# [libx264 @ 0x13af074a0] mb I  I16..4: 19.3% 62.1% 18.5%
# [libx264 @ 0x13af074a0] mb P  I16..4:  0.4%  0.4%  0.0%  P16..4: 18.8%  3.6%  2.9%  0.0%  0.0%    skip:73.9%
# [libx264 @ 0x13af074a0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 16.8%  0.1%  0.0%  direct: 0.1%  skip:83.0%  L0:41.7% L1:57.8% BI: 0.5%
# [libx264 @ 0x13af074a0] 8x8 transform intra:55.8% inter:68.6%
# [libx264 @ 0x13af074a0] coded y,uvDC,uvAC intra: 34.1% 41.7% 10.0% inter: 3.3% 3.4% 0.0%
# [libx264 @ 0x13af074a0] i16 v,h,dc,p: 44% 16% 21% 18%
# [libx264 @ 0x13af074a0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39%  9% 33%  3%  3%  4%  2%  4%  3%
# [libx264 @ 0x13af074a0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 12% 13%  5%  6%  8%  5%  6%  4%
# [libx264 @ 0x13af074a0] i8c dc,h,v,p: 62% 16% 17%  5%
# [libx264 @ 0x13af074a0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x13af074a0] ref P L0: 76.7%  8.4% 11.2%  3.8%
# [libx264 @ 0x13af074a0] ref B L0: 91.9%  7.1%  1.0%
# [libx264 @ 0x13af074a0] ref B L1: 97.1%  2.9%
# [libx264 @ 0x13af074a0] kb/s:197.89
# [aac @ 0x13af08570] Qavg: 131.277
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.1.2_6 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, matroska,webm, from 'QID160_1682631466760.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
#   Stream #0:1(eng): Video: h264 (Baseline), yuv420p(tv, bt709/bt709/iec61966-2-1, progressive), 640x480, SAR 1:1 DAR 4:3, 30 fps, 30 tbr, 1k tbn (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (opus (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14a609400] using SAR=1/1
# [libx264 @ 0x14a609400] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14a609400] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x14a609400] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/Users/sukruthgl/Desktop/Spring/CS 5999 - MEng Project/StudyData/pilots/7444/mp4StudyVideo/QID160_1682631466760.mp4':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709/bt709/iec61966-2-1, progressive), 640x480 [SAR 1:1 DAR 4:3], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       encoder         : Lavc59.37.100 aac
# frame= 1081 fps=887 q=-1.0 Lsize=    1148kB time=00:00:36.01 bitrate= 261.2kbits/s dup=2 drop=0 speed=29.6x
# video:806kB audio:305kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.336656%
# [libx264 @ 0x14a609400] frame I:5     Avg QP:18.16  size: 14714
# [libx264 @ 0x14a609400] frame P:633   Avg QP:19.96  size:  1053
# [libx264 @ 0x14a609400] frame B:443   Avg QP:18.43  size:   191
# [libx264 @ 0x14a609400] consecutive B-frames: 42.8%  6.3%  3.9% 47.0%
# [libx264 @ 0x14a609400] mb I  I16..4:  9.7% 70.8% 19.4%
# [libx264 @ 0x14a609400] mb P  I16..4:  0.4%  0.3%  0.0%  P16..4: 16.1%  2.6%  2.4%  0.0%  0.0%    skip:78.3%
# [libx264 @ 0x14a609400] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.3%  0.1%  0.0%  direct: 0.1%  skip:84.5%  L0:39.8% L1:59.9% BI: 0.3%
# [libx264 @ 0x14a609400] 8x8 transform intra:57.9% inter:68.8%
# [libx264 @ 0x14a609400] coded y,uvDC,uvAC intra: 38.1% 48.3% 13.5% inter: 2.9% 3.4% 0.0%
# [libx264 @ 0x14a609400] i16 v,h,dc,p: 39% 17% 26% 18%
# [libx264 @ 0x14a609400] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24%  9% 48%  3%  3%  4%  2%  4%  3%
# [libx264 @ 0x14a609400] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 12% 15%  6%  7%  8%  6%  6%  5%
# [libx264 @ 0x14a609400] i8c dc,h,v,p: 61% 15% 19%  4%
# [libx264 @ 0x14a609400] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x14a609400] ref P L0: 79.5%  6.4% 10.2%  4.0%
# [libx264 @ 0x14a609400] ref B L0: 92.1%  6.8%  1.1%
# [libx264 @ 0x14a609400] ref B L1: 97.3%  2.7%
# [libx264 @ 0x14a609400] kb/s:183.08
# [aac @ 0x14a60a4d0] Qavg: 208.233
# ffmpeg version 5.1.2 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 14.0.0 (clang-1400.0.29.202)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.1.2_6 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 28.100 / 57. 28.100
#   libavcodec     59. 37.100 / 59. 37.100
#   libavformat    59. 27.100 / 59. 27.100
#   libavdevice    59.  7.100 / 59.  7.100
#   libavfilter     8. 44.100 /  8. 44.100
#   libswscale      6.  7.100 /  6.  7.100
#   libswresample   4.  7.100 /  4.  7.100
#   libpostproc    56.  6.100 / 56.  6.100
# Input #0, matroska,webm, from 'QID898_1682631070892.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
#   Stream #0:1(eng): Video: h264 (Baseline), yuv420p(tv, bt709/bt709/iec61966-2-1, progressive), 640x480, SAR 1:1 DAR 4:3, 30 fps, 30 tbr, 1k tbn (default)
# Stream mapping:
#   Stream #0:1 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:0 -> #0:1 (opus (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x145f05e20] using SAR=1/1
# [libx264 @ 0x145f05e20] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x145f05e20] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x145f05e20] 264 - core 164 r3095 baee400 - H.264/MPEG-4 AVC codec - Copyleft 2003-2022 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/Users/sukruthgl/Desktop/Spring/CS 5999 - MEng Project/StudyData/pilots/7444/mp4StudyVideo/QID898_1682631070892.mp4':
#   Metadata:
#     encoder         : Lavf59.27.100
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709/bt709/iec61966-2-1, progressive), 640x480 [SAR 1:1 DAR 4:3], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       encoder         : Lavc59.37.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       encoder         : Lavc59.37.100 aac
# frame=  239 fps=0.0 q=-1.0 Lsize=     240kB time=00:00:07.93 bitrate= 247.2kbits/s dup=1 drop=0 speed=27.4x
# video:163kB audio:67kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.001357%
# [libx264 @ 0x145f05e20] frame I:1     Avg QP:17.82  size:  8640
# [libx264 @ 0x145f05e20] frame P:140   Avg QP:20.35  size:   975
# [libx264 @ 0x145f05e20] frame B:98    Avg QP:18.08  size:   214
# [libx264 @ 0x145f05e20] consecutive B-frames: 44.8%  1.7%  0.0% 53.6%
# [libx264 @ 0x145f05e20] mb I  I16..4: 13.8% 70.5% 15.8%
# [libx264 @ 0x145f05e20] mb P  I16..4:  0.3%  0.3%  0.0%  P16..4: 14.1%  2.7%  2.2%  0.0%  0.0%    skip:80.5%
# [libx264 @ 0x145f05e20] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 16.9%  0.1%  0.0%  direct: 0.1%  skip:82.9%  L0:35.7% L1:63.7% BI: 0.6%
# [libx264 @ 0x145f05e20] 8x8 transform intra:60.1% inter:68.6%
# [libx264 @ 0x145f05e20] coded y,uvDC,uvAC intra: 30.1% 35.1% 3.2% inter: 2.7% 2.5% 0.0%
# [libx264 @ 0x145f05e20] i16 v,h,dc,p: 44% 20% 17% 19%
# [libx264 @ 0x145f05e20] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 12% 33%  2%  2%  3%  2%  4%  2%
# [libx264 @ 0x145f05e20] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 44% 12% 12%  5%  6%  6%  6%  6%  3%
# [libx264 @ 0x145f05e20] i8c dc,h,v,p: 61% 17% 17%  5%
# [libx264 @ 0x145f05e20] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x145f05e20] ref P L0: 77.6%  8.9% 10.8%  2.7%
# [libx264 @ 0x145f05e20] ref B L0: 85.8% 12.8%  1.4%
# [libx264 @ 0x145f05e20] ref B L1: 96.6%  3.4%
# [libx264 @ 0x145f05e20] kb/s:166.82
# [aac @ 0x145f06ef0] Qavg: 132.430

# %%
# Iterates through all the studyUserData directories 
# and then creates a new directory and stores all the converted (".webm" to ".mp4") files in it

def convertVideo(studyUsers):
    
    for studyUser in studyUsers:

        studyUserDirectory = studyDataDirectory + f'/{studyUser}'

        # Creating a new directory to store the converted video files
        studyUser_mp4Directory = studyUserDirectory + '/mp4StudyVideo'
        os.mkdir(studyUser_mp4Directory)

        # Changing the current working directory to the studyUserDirectory for the glob file to search for ".webm" video files
        os.chdir(studyUserDirectory)

        for video in glob.glob("*.webm"):
            output_video = os.path.join(studyUser_mp4Directory, f"{os.path.splitext(video)[0]}.mp4")
            subprocess.run(["ffmpeg", "-i", video, "-r", "30", output_video])
